# %%
# %pip install openai-whisper
import whisper
# Out:
# ...
#      ---------------------------------------- 0.0/803.2 kB ? eta -:--:--
#      ------------------------------------- 803.2/803.2 kB 23.8 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 2.7/2.7 MB 52.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/37.9 MB ? eta -:--:--
#    -------------------- ------------------- 19.4/37.9 MB 92.0 MB/s eta 0:00:01
#    ---------------------------------------  37.7/37.9 MB 100.6 MB/s eta 0:00:01
#    ---------------------------------------- 37.9/37.9 MB 80.7 MB/s eta 0:00:00
# ...

# %%
model = whisper.load_model("small")
result = model.transcribe("./Assets/Audio/Desafios.mp3") # cambiar los espacios en el nombre del archivo
print(result["text"])
# Out:
# c:\Users\Brayan\AppData\Local\Programs\Python\Python313\Lib\site-packages\whisper\transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[24], line 2
#       1 model = whisper.load_model("small")
# ----> 2 result = model.transcribe("C:/Users/Brayan/Desktop/PROYECTOS/ONE/IA explorando el potencial de la IA generativa/Assets/Audio/Desafios.mp3")
#       3 print(result["text"])
#
# ...
